# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt') 

results = model.train(
    data='../data/pets_yolo_dataset/pets.yaml',  
    epochs=12,         
    imgsz=640,         
    batch=16,          
    device='mps'      
)
# Out:
# Ultralytics 8.4.33 🚀 Python-3.10.19 torch-2.10.0 MPS (Apple M1 Pro)
# ...
